# %%
A = [0.02 0; 0 0.02]
# Out:
# 2×2 Matrix{Float64}:
#  0.02  0.0
#  0.0   0.02

# %%
using Plots
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
y = x = -3:0.5:3
f(x1, x2) = begin
    x = [x1,x2]
    exp(2*transpose(x)*A*x)
end
plot(contour(x,y,f))
# Out:
#     <div id="4766183a-0fad-440f-a4d3-a1c26b3af1a8" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('4766183a-0fad-440f-a4d3-a1c26b3af1a8');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(0, 0, 4, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(1, 0, 5, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(1, 1, 6, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(1, 1, 8, 1.000)"
#             ],
#             [
# ...
